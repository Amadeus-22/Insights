# %%
import pandas as pd

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_apps =pd.read_csv('apps.csv')

# %%
print(df_apps.shape)
print(df_apps.sample(5))
# Out:
# (10841, 12)
#                              App        Category  Rating  Reviews  Size_MBs  \
# 3910                  CP Clicker       LIFESTYLE    4.20      251      5.00
# 8133      Sky Streaker - Gumball            GAME    4.30    37513     31.00
# 4234  Tamilnadu Electricity Info           TOOLS    3.60      216      0.79
# 6907    GialloZafferano: Recipes  FOOD_AND_DRINK    4.30    30224     14.50
# 2530        W-History Standalone          SOCIAL    3.20       38      1.50
#
#        Installs  Type  Price Content_Rating        Genres      Last_Updated  \
# 3910     10,000  Free      0       Everyone     Lifestyle    March 22, 2018
# 8133  5,000,000  Free      0       Everyone        Arcade  December 7, 2015
# 4234     10,000  Free      0       Everyone         Tools  November 9, 2014
# 6907  1,000,000  Free      0       Everyone  Food & Drink      May 28, 2018
# 2530      1,000  Paid  $0.99       Everyone        Social     March 9, 2018
#
#              Android_Ver
# ...

# %%
print(df_apps.head)
# Out:
# <bound method NDFrame.head of                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
# ...

# %%
print(df_apps.isnull().values.any())
print(f'number of null values:{df_apps.isnull().sum()}')
# Out:
# True
# number of null values:App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# Last_Updated         0
# Android_Ver          2
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()
print(df_apps_clean.isnull().values.any())
# Out:
# False

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
print(duplicated_rows.shape)
print(duplicated_rows.head)
# Out:
# (474, 12)
# <bound method NDFrame.head of                                               App            Category  Rating  \
# 946                        420 BZ Budeze Delivery             MEDICAL    5.00
# 1133                                  MouseMingle              DATING    2.70
# 1196   Cardiac diagnosis (heart rate, arrhythmia)             MEDICAL    4.40
# 1231                                 Sway Medical             MEDICAL    5.00
# 1247               Chat Kids - Chat Room For Kids              DATING    4.70
# ...                                           ...                 ...     ...
# 10802               Skype - free IM & video calls       COMMUNICATION    4.10
# 10809                                   Instagram              SOCIAL    4.50
# 10826                                Google Drive        PRODUCTIVITY    4.40
# 10832                                 Google News  NEWS_AND_MAGAZINES    3.90
# ...

# %%
df_apps_clean[df_apps_clean["App"] =='Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10806     0           Teen  Social  July 31, 2018  Varies with device
# 10808     0           Teen  Social  July 31, 2018  Varies with device
# 10809     0           Teen  Social  July 31, 2018  Varies with device
# 10810     0           Teen  Social  July 31, 2018  Varies with device

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])

# %%
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10806     0           Teen  Social  July 31, 2018  Varies with device

# %%
df_apps_clean.sort_values('Rating', ascending=False).head(10)
# Out:
#                                            App            Category  Rating  \
# 21                         KBA-EZ Health Guide             MEDICAL    5.00
# 1790                          SUMMER SONIC app              EVENTS    5.00
# 1769  Yazdani Cd Center EllahAbad Official App              FAMILY    5.00
# 985                                DW Security            BUSINESS    5.00
# 981                               EU Exit poll           LIFESTYLE    5.00
# 1772                               Victoria EC               TOOLS    5.00
# 979                      NOMISMA.com.cy by FMW  NEWS_AND_MAGAZINES    5.00
# 1780                            CD CHOICE TUBE              FAMILY    5.00
# 1789                                   Ek Vote        PRODUCTIVITY    5.00
# 958       Food-Aw - Order Food Online in Aruba      FOOD_AND_DRINK    5.00
#
#       Reviews  Size_MBs Installs  Type Price Content_Rating            Genres  \
# ...

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head(5)
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres    Last_Updated Android_Ver
# 9942   Lifestyle;Pretend Play   July 16, 2018  4.0 and up
# 10687                  Arcade   July 25, 2018  4.1 and up
# ...

# %%
top_50= df_apps_clean.sort_values('Reviews', ascending=False).head(1000)

top_50[top_50['Type'] == 'Paid']
# Out:
#                                 App Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft   FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper     GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas     GAME    4.40   348962     26.00
#
#         Installs  Type  Price Content_Rating                     Genres  \
# 9220  10,000,000  Paid  $6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10,000,000  Paid  $0.99     Mature 17+                     Action
# 7151   1,000,000  Paid  $6.99     Mature 17+                     Action
#
#         Last_Updated         Android_Ver
# 9220   July 24, 2018  Varies with device
# 8825   July 12, 2018          4.1 and up
# 7151  March 21, 2015          3.0 and up

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
print(df_paid_apps)
# Out:
#                                                     App   Category  Rating  \
# 28                                             Ra Ga Ba       GAME    5.00
# 47                                              Mu.F.O.       GAME    5.00
# 233              Chess of Blades (BL/Yaoi Game) (No VA)     FAMILY    4.80
# 248                                        The DG Buddy   BUSINESS    3.70
# 291                                 AC DC Power Monitor  LIFESTYLE    5.00
# ...                                                 ...        ...     ...
# 7957  League of Stickman 2018- Ninja Arena PVP(Dream...       GAME    4.40
# 7977                            Sleep as Android Unlock  LIFESTYLE    4.50
# 7988                                  Where's My Water?     FAMILY    4.70
# 8825                                      Hitman Sniper       GAME    4.60
# 9220                                          Minecraft     FAMILY    4.50
#
#       Reviews  Size_MBs    Installs  Type   Price Content_Rating  \
# ...
